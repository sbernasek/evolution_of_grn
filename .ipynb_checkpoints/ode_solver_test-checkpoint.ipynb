# %%
from main import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
cell = Cell(1, permanent_genes=2)

# mutate cell
for _ in range(0, 100):
    _, cell = cell.divide(2)

# %%
disturbances = [(0, 0), (10, 1), (20, 2), (100, 5)]

times, states, energy, key = cell.simulate_2(disturbances, input_node=2, ic=None, retall=True)

# %%
for state in states.T:
    plt.plot(times, state)

# sol = odeint(f, initial_states, times, args=(stoich))

# %%
plt.plot(times, states[:, 1], '.-r')

# %%
states
# Out:
# array([ 0.+0.j,  0.+0.j])
