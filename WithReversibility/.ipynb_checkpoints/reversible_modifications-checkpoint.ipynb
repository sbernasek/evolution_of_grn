# %%
from main import *
import matplotlib.pyplot as plt
import time 
import copy as copy

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# run evolutionary procedure

# simulation parameters
generations = 10 # number of selection/growth cycles
population_size = 10 # total number of cells in each generation
mutations_per_division = 2 # number of mutations applied per cell-division

# temp parameters
cells_selected = 5 # number of cells selected


# initialize cell population as a single cell with 3 genes
population = [Cell(name=1, initial_genes=2, permanent_genes=1)]

# grow to desired population
while len(population) < population_size:
    # clone and mutate a randomly selected cell
    cell = np.random.choice(population)    
    cell, mutant = cell.divide(num_mutations=mutations_per_division)
    population.append(mutant)
    
# iterate through selection+growth cycles
for gen in range(0, generations):
    
    # get topology distribution for current generation's networks
    edge_counts, node_counts = zip(*list(map(lambda x:(len(x[0]), len(x[1])), [cell.get_topology() for cell in population])))
    #print('Generation', gen, ': %g edges in average network' % np.mean(edge_counts))
    
    # SELECTION
    
    # RUN DYNAMICS AND SCORE EACH CELL
    
    # SELECT CELLS ON PARETO FRONT
    population = list(np.random.choice(population, size=cells_selected))
    
    # grow ramining cells back to desired population size
    while len(population) < population_size:
        # clone and mutate a randomly selected cell
        cell = np.random.choice(population)    
        _, mutant = cell.divide(num_mutations=mutations_per_division)
        population.append(mutant)
        
# show topology of a random cell in the final population
random_cell = np.random.choice(population)
random_cell.show_topology(graph_layout='shell')

# get some basic distribution statistics
age_distribution = [cell.name for cell in population]
edge_count_distribution, node_count_distribution = zip(*list(map(lambda x:(len(x[0]), len(x[1])), [cell.get_topology() for cell in population])))
network_gene_count_distribution = [len(cell.removable_genes+cell.non_coding_rnas) for cell in population]

# %%
# run a dynamic simulation and plot all species trajectories

# create disturbance (for now, no influence. just sets timecourse)
active_species = len(random_cell.coding_rnas + random_cell.non_coding_rnas + random_cell.proteins)
disturbances = Signal('disturbance', duration=20, dt=0.01, signal=None, channels=active_species)

# set initial condition
ic = np.ones(active_species)

# run simulation
states, energy = random_cell.simulate(disturbances, ic=ic, mode='tau_leaping')

# plot all species trajectories
for species in range(0, len(states[:, 0])):
    plt.plot(disturbances.time, states[species, :])
ax = plt.gca()
ax.set_xlabel('Time', fontsize=14)
ax.set_ylabel('Level', fontsize=14)

# %%
# plot a single species
species = 5
plt.plot(disturbances.time, states[species, :])
ax.set_xlabel('Time', fontsize=14)
ax.set_ylabel('Level', fontsize=14)

# %%
# sequentially mutate a single cell
generations = 5 # number of selection/growth cycles
mutations = 2 # number of mutations applied per cell-division

# initialize cell population as a single cell with 3 genes
cell = Cell(name=1, initial_genes=2)

# iterate through selection+growth cycles
for gen in range(0, generations):
    
    # clone and mutate a single cell
    _, cell = cell.divide(num_mutations=mutations)
    cell.show_topology()
# Out:
# Network has no edges.

# %%
# create custom network

# initialize cell with one gene
cell = Cell(name=1, initial_genes=1)

N_add = 10
# add N modifications
for _ in range(0, N_add):
    cell.add_protein_modification()
    
N_remove = 2
# remove N modifications
for _ in range(0, N_remove):
    cell.remove_protein_modification()

cell.show_topology()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-134-63c9c96b7863> in <module>()
#      14     cell.remove_protein_modification()
#      15
# ---> 16 cell.show_topology()
#
# /Users/Sebi/Documents/GradSchool/Evolution_of_GRNs/Evolution_of_GRN/WithReversibility/modules/cells.py in show_topology(self, graph_layout)
#     739
#     740         # get network topology
# --> 741         edge_list, node_labels = self.get_topology()
#     742
#     743         if len(edge_list) == 0:
#
# /Users/Sebi/Documents/GradSchool/Evolution_of_GRNs/Evolution_of_GRN/WithReversibility/modules/cells.py in get_topology(self)
#     722                 edge_list.append(edge)
#     723             if rxn.rxn_type == 'modification':
# --> 724                 edge = (node_key[rxn.reactants[0]], node_key[rxn.products[0]], rxn.rxn_type)
#     725                 edge_list.append(edge)
#     726             if rxn.rxn_type == 'catalytic_modification':
#
# KeyError: 4

# %%
# cell_copy = copy.deepcopy(cell)
# cell_copy.show_topology()
# cell.proteins

# %%
for rxn in cell.reactions:
    print('type', rxn.rxn_type, 'reactants', rxn.reactants)
# Out:
# type transcription reactants []
# type mrna_decay reactants [0]
# type translation reactants [0]
# type protein_decay reactants [1]
# type protein_decay reactants [2]
# type modification reactants [1]
# type modification reactants [2]
# type modification reactants [2]
# type modification reactants [2]
# type protein_decay reactants [3]
# type catalytic_modification reactants [1, 3]
# type modification reactants [2]
# type modification reactants [4]
# type modification reactants [3]

# %%
print(cell.proteins)
print(cell.modified_proteins)


cell.get_topology()
# Out:
# [1, 2, 3]
# [2, 3]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-138-1df72d089db0> in <module>()
#       3
#       4
# ----> 5 cell.get_topology()
#
# /Users/Sebi/Documents/GradSchool/Evolution_of_GRNs/Evolution_of_GRN/WithReversibility/modules/cells.py in get_topology(self)
#     722                 edge_list.append(edge)
#     723             if rxn.rxn_type == 'modification':
# --> 724                 edge = (node_key[rxn.reactants[0]], node_key[rxn.products[0]], rxn.rxn_type)
#     725                 edge_list.append(edge)
#     726             if rxn.rxn_type == 'catalytic_modification':
#
# KeyError: 4

# %%
# create custom network
for _ in range(0, 10):
    # initialize cell with one gene
    cell = Cell(name=1, initial_genes=1)

    N_add = 4
    # add N modifications
    for _ in range(0, N_add):
        cell.add_protein_modification()

    print('initial mods:')
    show_mods(cell)

    print('\n')
    # remove N modifications
    N_remove = 4
    for i in range(0, N_remove):

        print('Round ', i)
        cell.remove_protein_modification()
        show_mods(cell)
        _ = cell.get_topology()
# Out:
# initial mods:
# Modifications
# [1] [2]
# [2] [1]
#
#
# Catalytic Modifications
# [1, 2] [3]
# [1, 3] [4]
#
#
# Round  0
# Modifications
# [1] [2]
# [2] [1]
#
#
# Catalytic Modifications
# Round  1
# Modifications
# [1] [2]
#
#
# Catalytic Modifications
# Round  2
# Modifications
#
#
# Catalytic Modifications
# Round  3
# Modifications
#
#
# Catalytic Modifications
# initial mods:
# Modifications
# [1] [2]
#
#
# Catalytic Modifications
# [1, 2] [3]
# [3, 2] [4]
# [1, 4] [5]
#
#
# Round  0
# Modifications
# [1] [2]
#
#
# Catalytic Modifications
# [1, 2] [3]
# [3, 2] [4]
# Round  1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-450-6e231ee3b981> in <module>()
#      19
#      20         print('Round ', i)
# ---> 21         cell.remove_protein_modification()
#      22         show_mods(cell)
#      23         _ = cell.get_topology()
#
# /Users/Sebi/Documents/GradSchool/Evolution_of_GRNs/Evolution_of_GRN/WithReversibility/modules/cells.py in remove_protein_modification(self)
#     515
#     516             # remove all protein isomers and their dependencies
# --> 517             self.remove_isomers(modified_protein)
#     518
#     519     def compile_stoichiometry(self, key):
#
# /Users/Sebi/Documents/GradSchool/Evolution_of_GRNs/Evolution_of_GRN/WithReversibility/modules/cells.py in remove_isomers(self, protein)
#     244
#     245                 # remove isomer
# --> 246                 self.proteins.remove(isomer)
#     247                 self.modified_proteins.remove(isomer)
#     248
#
# ValueError: list.remove(x): x not in list

# %%
cell.proteins
# Out:
# [1]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-686-0655c9dda312> in <module>()
#      16     for i in range(0, N_remove):
#      17         cell.remove_protein_modification()
# ---> 18         _ = cell.get_topology()
#
# /Users/Sebi/Documents/GradSchool/Evolution_of_GRNs/Evolution_of_GRN/WithReversibility/modules/cells.py in get_topology(self)
#     767                 edge_list.append(edge)
#     768             if rxn.rxn_type == 'modification':
# --> 769                 edge = (node_key[rxn.reactants[0]], node_key[rxn.products[0]], rxn.rxn_type)
#     770                 edge_list.append(edge)
#     771             if rxn.rxn_type == 'catalytic_modification':
#
# KeyError: 3

# %%
def show_mods(cell):
    print('Modifications')
    for rxn in cell.reactions:
        if rxn.rxn_type == 'modification':
            print(rxn.reactants, rxn.products)
    print('\n')
    print('Catalytic Modifications')
    for rxn in cell.reactions:
        if rxn.rxn_type == 'catalytic_modification':
            print(rxn.reactants, rxn.products)

# %%
for rxn in cell.reactions:
    print('type', rxn.rxn_type, 'reactants', rxn.reactants, 'products', rxn.products)
# Out:
# type transcription reactants [] products [0]
# type mrna_decay reactants [0] products []
# type translation reactants [0] products [1]
# type protein_decay reactants [1] products []
# type modification reactants [1] products [2]

# %%
cell = Cell(name=1, initial_genes=1)

cell.add_protein_modification(substrate=1)
cell.add_protein_modification(substrate=1, enzyme=2)
cell.add_protein_modification(substrate=3, enzyme=2, reversibility_bias=0)

cell.remove_protein_modification()

cell.show_topology()

# %%
# DEBUGGING - INITIALIZE SHIT TONS OF NETWORKS TO FIND MESSED UP ONES

for _ in range(0, 100):
    
    # initialize cell with one gene
    cell = Cell(name=1, initial_genes=1)

    N_add = 10
    # add N modifications
    for _ in range(0, N_add):
        cell.add_protein_modification()
    
    rxn_list = []
    rxn_list.append(cell.reactions)
    
    protein_list = []
    protein_list.append(cell.proteins)
    # remove N modifications
    N_remove = 1
    for i in range(0, N_remove):    
        cell.remove_protein_modification()
        protein_list.append(cell.proteins)
        rxn_list.append(cell.reactions)
        _ = cell.get_topology()
# Out:
# before removal
# [1] [2]
# [2] [1]
# [2] [3]
# [2, 1] [1]
# [1] [4]
# [3, 1] [2]
# [3] [2]
# [4, 3] [1]
# [3, 5] [5]
# [2] [6]
#
#
# removed: [3] [2]
#
#
# after removal
# [1] [2]
# [2] [1]
# [2] [3]
# [2, 1] [1]
# [1] [4]
# [3, 1] [2]
# [4, 3] [1]
# [3, 5] [5]
# [2] [6]
#
#
#
#
# before removal
# [1] [2]
# [2] [3]
# [2, 4] [4]
# [4] [2]
# [4, 5] [5]
# [3] [2]
# [1] [6]
# [1] [7]
# [2] [4]
# [4, 5] [2]
#
#
# removed: [4, 5] [2]
#
#
# after removal
# [1] [2]
# [2] [3]
# [2, 4] [4]
# [4] [2]
# [4, 5] [5]
# [3] [2]
# [1] [6]
# [1] [7]
# [2] [4]
#
#
#
#
# before removal
# [1] [2]
# [1] [3]
# [2, 3] [1]
# [3] [1]
# [3, 1] [1]
# [3] [4]
# [4] [3]
# [1] [5]
# [3] [6]
# [6] [7]
#
#
# removed: [2, 3] [1]
#
#
# after removal
# [1] [2]
# [1] [3]
# [3] [1]
# [3, 1] [1]
# [3] [4]
# [4] [3]
# [1] [5]
# [3] [6]
# [6] [7]
#
#
#
#
# before removal
# [1] [2]
# [2] [3]
# [3] [2]
# [2] [4]
# [1, 3] [5]
# [4, 2] [6]
# [4, 7] [7]
# [5, 2] [8]
# [5, 8] [1]
# [4, 1] [9]
#
#
# removed: [1, 3] [5]
#
#
# isomer_queue [8]
# removing:  8
# going downstream
# isomer_queue []
# removed downstream:  []
# after removal
# [1] [2]
# [2] [3]
# [3] [2]
# [2] [4]
# [4, 2] [6]
# [4, 7] [7]
# [4, 1] [9]
#
#
#
#
# before removal
# [1] [2]
# [2] [1]
# [1] [3]
# [2, 1] [4]
# [2] [5]
# [2] [6]
# [4, 7] [7]
# [3] [8]
# [3] [1]
# [1, 4] [9]
#
#
# removed: [3] [1]
#
#
# after removal
# [1] [2]
# [2] [1]
# [1] [3]
# [2, 1] [4]
# [2] [5]
# [2] [6]
# [4, 7] [7]
# [3] [8]
# [1, 4] [9]
#
#
#
#
# before removal
# [1] [2]
# [2, 1] [3]
# [1, 3] [4]
# [4] [5]
# [1, 6] [6]
# [4, 7] [7]
# [7, 6] [4]
# [6] [8]
# [7, 6] [9]
# [5, 7] [4]
#
#
# removed: [1, 6] [6]
#
#
# isomer_queue [8, 9]
# removing:  8
# going downstream
# isomer_queue []
# removed downstream:  []
# removing:  9
# going downstream
# isomer_queue []
# removed downstream:  []
# after removal
# [1] [2]
# [2, 1] [3]
# [1, 3] [4]
# [4] [5]
# [4, 7] [7]
# [5, 7] [4]
#
#
#
#
# before removal
# [1] [2]
# [2, 3] [3]
# [3] [2]
# [1] [4]
# [3] [5]
# [1, 6] [6]
# [6] [1]
# [4, 3] [1]
# [6, 4] [1]
# [5, 7] [7]
#
#
# removed: [3] [2]
#
#
# after removal
# [1] [2]
# [2, 3] [3]
# [1] [4]
# [3] [5]
# [1, 6] [6]
# [6] [1]
# [4, 3] [1]
# [6, 4] [1]
# [5, 7] [7]
#
#
#
#
# before removal
# [1] [2]
# [1] [3]
# [3] [4]
# [3, 1] [5]
# [2, 4] [6]
# [4] [3]
# [4, 5] [7]
# [6, 2] [8]
# [8] [6]
# [4, 6] [3]
#
#
# removed: [6, 2] [8]
#
#
# isomer_queue []
# after removal
# [1] [2]
# [1] [3]
# [3] [4]
# [3, 1] [5]
# [2, 4] [6]
# [4] [3]
# [4, 5] [7]
# [4, 6] [3]
#
#
#
#
# before removal
# [1] [2]
# [2] [1]
# [1] [3]
# [2, 3] [1]
# [1, 2] [4]
# [4] [1]
# [1] [5]
# [1] [6]
# [3, 2] [7]
# [1] [8]
#
#
# removed: [2] [1]
#
#
# after removal
# [1] [2]
# [1] [3]
# [2, 3] [1]
# [1, 2] [4]
# [4] [1]
# [1] [5]
# [1] [6]
# [3, 2] [7]
# [1] [8]
#
#
#
#
# before removal
# [1] [2]
# [1] [3]
# [2] [4]
# [3] [5]
# [2] [1]
# [5, 3] [3]
# [3] [6]
# [5, 1] [3]
# [1] [7]
# [4, 7] [8]
#
#
# removed: [3] [5]
#
#
# isomer_queue []
# after removal
# [1] [2]
# [1] [3]
# [2] [4]
# [2] [1]
# [3] [6]
# [1] [7]
# [4, 7] [8]
#
#
#
#
# before removal
# [1] [2]
# [1] [3]
# [3] [4]
# [3] [5]
# [2] [6]
# [3] [7]
# [1] [8]
# [5] [3]
# [7, 9] [9]
# [9] [10]
#
#
# removed: [1] [2]
#
#
# isomer_queue [6]
# removing:  6
# going downstream
# isomer_queue []
# removed downstream:  []
# after removal
# [1] [3]
# [3] [4]
# [3] [5]
# [3] [7]
# [1] [8]
# [5] [3]
# [7, 9] [9]
# [9] [10]
#
#
#
#
# before removal
# [1] [2]
# [1, 2] [3]
# [2] [4]
# [4, 3] [2]
# [4] [2]
# [3] [1]
# [4, 2] [2]
# [4] [5]
# [1, 3] [6]
# [6, 4] [7]
#
#
# removed: [1] [2]
#
#
# isomer_queue [3, 4]
# removing:  3
# going downstream
# isomer_queue [6]
# removing:  6
# going downstream
# isomer_queue [7]
# removing:  7
# going downstream
# isomer_queue []
# removed downstream:  []
# removed downstream:  [7]
# removed downstream:  [7, 6]
# removing:  4
# going downstream
# isomer_queue [5]
# removing:  5
# going downstream
# isomer_queue []
# removed downstream:  []
# removed downstream:  [5]
# after removal
#
#
#
#
# before removal
# [1] [2]
# [2] [1]
# [1, 2] [3]
# [2] [4]
# [1] [5]
# [4, 6] [6]
# [2] [7]
# [6, 2] [8]
# [8] [6]
# [5] [1]
#
#
# removed: [1] [5]
#
#
# isomer_queue []
# after removal
# [1] [2]
# [2] [1]
# [1, 2] [3]
# [2] [4]
# [4, 6] [6]
# [2] [7]
# [6, 2] [8]
# [8] [6]
#
#
#
#
# before removal
# [1] [2]
# [2] [1]
# [1] [3]
# [1, 4] [4]
# [4] [5]
# [3] [1]
# [4] [1]
# [5, 3] [4]
# [2, 5] [1]
# [2, 4] [1]
#
#
# removed: [1] [3]
#
#
# isomer_queue [4]
# removing:  4
# going downstream
# isomer_queue [5]
# removing:  5
# going downstream
# isomer_queue []
# removed downstream:  []
# removed downstream:  [5]
# after removal
# [1] [2]
# [2] [1]
#
#
#
#
# before removal
# [1] [2]
# [1, 2] [3]
# [1, 2] [4]
# [1, 2] [5]
# [3, 4] [1]
# [1, 4] [6]
# [6, 2] [7]
# [7, 2] [6]
# [3, 1] [1]
# [7] [6]
#
#
# removed: [3, 4] [1]
#
#
# after removal
# [1] [2]
# [1, 2] [3]
# [1, 2] [4]
# [1, 2] [5]
# [1, 4] [6]
# [6, 2] [7]
# [7, 2] [6]
# [3, 1] [1]
# [7] [6]
#
#
#
#
# before removal
# [1] [2]
# [1] [3]
# [1] [4]
# [1] [5]
# [4] [1]
# [2, 4] [1]
# [5, 2] [1]
# [4, 3] [1]
# [4, 3] [6]
# [1] [7]
#
#
# removed: [4, 3] [6]
#
#
# isomer_queue []
# after removal
# [1] [2]
# [1] [3]
# [1] [4]
# [1] [5]
# [4] [1]
# [2, 4] [1]
# [5, 2] [1]
# [4, 3] [1]
# [1] [7]
#
#
#
#
# before removal
# [1] [2]
# [1, 2] [3]
# [2, 4] [4]
# [3, 5] [5]
# [5, 1] [3]
# [3, 1] [6]
# [6, 3] [3]
# [2, 6] [7]
# [3, 7] [8]
# [4] [2]
#
#
# removed: [4] [2]
#
#
# after removal
# [1] [2]
# [1, 2] [3]
# [2, 4] [4]
# [3, 5] [5]
# [5, 1] [3]
# [3, 1] [6]
# [6, 3] [3]
# [2, 6] [7]
# [3, 7] [8]
#
#
#
#
# before removal
# [1] [2]
# [2] [1]
# [2, 1] [3]
# [3, 1] [2]
# [1, 3] [4]
# [4] [5]
# [1] [6]
# [4] [1]
# [3] [7]
# [7] [8]
#
#
# removed: [4] [1]
#
#
# after removal
# [1] [2]
# [2] [1]
# [2, 1] [3]
# [3, 1] [2]
# [1, 3] [4]
# [4] [5]
# [1] [6]
# [3] [7]
# [7] [8]
#
#
#
#
# before removal
# [1] [2]
# [1, 2] [3]
# [2] [1]
# [1] [4]
# [4] [5]
# [1, 6] [6]
# [2] [7]
# [4, 1] [8]
# [6, 7] [1]
# [4] [9]
#
#
# removed: [6, 7] [1]
#
#
# after removal
# [1] [2]
# [1, 2] [3]
# [2] [1]
# [1] [4]
# [4] [5]
# [1, 6] [6]
# [2] [7]
# [4, 1] [8]
# [4] [9]
#
#
#
#
# before removal
# [1] [2]
# [2] [1]
# [1] [3]
# [3, 2] [1]
# [3, 2] [4]
# [2] [5]
# [2, 5] [6]
# [1] [7]
# [2, 4] [1]
# [1] [8]
#
#
# removed: [1] [2]
#
#
# isomer_queue [4, 5, 6]
# removing:  4
# going downstream
# isomer_queue []
# removed downstream:  []
# removing:  5
# going downstream
# isomer_queue [6]
# removing:  6
# going downstream
# isomer_queue []
# removed downstream:  []
# removed downstream:  [6]
# after removal
# [1] [3]
# [1] [7]
# [1] [8]
#
#
#
#
# before removal
# [1] [2]
# [2] [1]
# [1] [3]
# [1, 2] [4]
# [1, 4] [5]
# [2, 1] [1]
# [5] [6]
# [3, 7] [7]
# [7, 1] [3]
# [2, 6] [8]
#
#
# removed: [1] [2]
#
#
# isomer_queue [4, 8]
# removing:  4
# going downstream
# isomer_queue [5]
# removing:  5
# going downstream
# isomer_queue [6]
# removing:  6
# going downstream
# isomer_queue [8]
# removing:  8
# going downstream
# isomer_queue []
# removed downstream:  []
# removed downstream:  [8]
# removed downstream:  [8, 6]
# removed downstream:  [8, 6, 5]
# after removal
# [1] [3]
# [3, 7] [7]
# [7, 1] [3]
#
#
#
#
# before removal
# [1] [2]
# [2] [1]
# [2] [3]
# [3, 1] [2]
# [2, 4] [4]
# [4] [2]
# [3] [2]
# [1, 4] [5]
# [3, 2] [6]
# [5] [7]
#
#
# removed: [3, 2] [6]
#
#
# isomer_queue []
# after removal
# [1] [2]
# [2] [1]
# [2] [3]
# [3, 1] [2]
# [2, 4] [4]
# [4] [2]
# [3] [2]
# [1, 4] [5]
# [5] [7]
#
#
#
#
# before removal
# [1] [2]
# [2] [1]
# [2, 3] [3]
# [3] [4]
# [4, 1] [5]
# [2, 4] [6]
# [1] [7]
# [2] [8]
# [4, 2] [9]
# [4, 2] [3]
#
#
# removed: [2] [8]
#
#
# isomer_queue []
# after removal
# [1] [2]
# [2] [1]
# [2, 3] [3]
# [3] [4]
# [4, 1] [5]
# [2, 4] [6]
# [1] [7]
# [4, 2] [9]
# [4, 2] [3]
#
#
#
#
# before removal
# [1] [2]
# [2, 1] [3]
# [2] [4]
# [1, 2] [5]
# [2] [1]
# [2, 4] [6]
# [6] [7]
# [1] [8]
# [8, 7] [9]
# [9, 10] [10]
#
#
# removed: [1] [8]
#
#
# isomer_queue [9]
# removing:  9
# going downstream
# isomer_queue [10]
# removing:  10
# going downstream
# isomer_queue []
# removed downstream:  []
# removed downstream:  [10]
# after removal
# [1] [2]
# [2, 1] [3]
# [2] [4]
# [1, 2] [5]
# [2] [1]
# [2, 4] [6]
# [6] [7]
#
#
#
#
# before removal
# [1] [2]
# [1] [3]
# [3] [1]
# [3] [4]
# [4, 1] [5]
# [4] [6]
# [4, 5] [3]
# [2] [1]
# [6, 1] [7]
# [5] [4]
#
#
# removed: [1] [3]
#
#
# isomer_queue [4]
# removing:  4
# going downstream
# isomer_queue [5, 6]
# removing:  5
# going downstream
# isomer_queue []
# removed downstream:  []
# removing:  6
# going downstream
# isomer_queue [7]
# removing:  7
# going downstream
# isomer_queue []
# removed downstream:  []
# removed downstream:  [7]
# removed downstream:  [7, 5, 6]
# after removal
# [1] [2]
# [2] [1]
#
#
#
#
# before removal
# [1] [2]
# [1, 3] [3]
# [1] [4]
# [1, 2] [5]
# [2] [1]
# [4, 2] [6]
# [2, 4] [1]
# [3] [7]
# [1, 5] [8]
# [6] [4]
#
#
# removed: [1, 3] [3]
#
#
# isomer_queue [7]
# removing:  7
# going downstream
# isomer_queue []
# removed downstream:  []
# after removal
# [1] [2]
# [1] [4]
# [1, 2] [5]
# [2] [1]
# [4, 2] [6]
# [2, 4] [1]
# [1, 5] [8]
# [6] [4]
#
#
#
#
# before removal
# [1] [2]
# [2] [1]
# [1] [3]
# [2, 1] [1]
# [1] [4]
# [1] [5]
# [1] [6]
# [1, 3] [7]
# [2, 1] [8]
# [5] [1]
#
#
# removed: [2, 1] [8]
#
#
# isomer_queue []
# after removal
# [1] [2]
# [2] [1]
# [1] [3]
# [2, 1] [1]
# [1] [4]
# [1] [5]
# [1] [6]
# [1, 3] [7]
# [5] [1]
#
#
#
#
# before removal
# [1] [2]
# [1] [3]
# [1] [4]
# [4] [5]
# [5] [6]
# [3] [7]
# [2] [1]
# [4, 5] [1]
# [3] [1]
# [4, 5] [8]
#
#
# removed: [1] [3]
#
#
# isomer_queue [7]
# removing:  7
# going downstream
# isomer_queue []
# removed downstream:  []
# after removal
# [1] [2]
# [1] [4]
# [4] [5]
# [5] [6]
# [2] [1]
# [4, 5] [1]
# [4, 5] [8]
#
#
#
#
# before removal
# [1] [2]
# [2] [1]
# [1] [3]
# [2] [4]
# [1, 4] [5]
# [2, 5] [1]
# [3, 1] [6]
# [4, 2] [2]
# [1, 6] [7]
# [5] [8]
#
#
# removed: [2, 5] [1]
#
#
# after removal
# [1] [2]
# [2] [1]
# [1] [3]
# [2] [4]
# [1, 4] [5]
# [3, 1] [6]
# [4, 2] [2]
# [1, 6] [7]
# [5] [8]
#
#
#
#
# before removal
# [1] [2]
# [1, 2] [3]
# [3] [1]
# [1, 3] [4]
# [1, 5] [5]
# [5, 3] [1]
# [3] [6]
# [3, 4] [7]
# [1] [8]
# [5, 3] [9]
#
#
# removed: [3, 4] [7]
#
#
# isomer_queue []
# after removal
# [1] [2]
# [1, 2] [3]
# [3] [1]
# [1, 3] [4]
# [1, 5] [5]
# [5, 3] [1]
# [3] [6]
# [1] [8]
# [5, 3] [9]
#
#
#
#
# before removal
# [1] [2]
# [1, 2] [3]
# [1, 3] [4]
# [4] [5]
# [2, 3] [6]
# [6] [2]
# [6] [7]
# [6, 5] [2]
# [7] [8]
# [4] [9]
#
#
# removed: [4] [9]
#
#
# isomer_queue []
# after removal
# [1] [2]
# [1, 2] [3]
# [1, 3] [4]
# [4] [5]
# [2, 3] [6]
# [6] [2]
# [6] [7]
# [6, 5] [2]
# [7] [8]
#
#
#
#
# before removal
# [1] [2]
# [1] [3]
# [2] [4]
# [2] [1]
# [1] [5]
# [2, 1] [6]
# [4] [7]
# [6] [8]
# [8, 3] [6]
# [1] [9]
#
#
# removed: [1] [2]
#
#
# isomer_queue [4, 6]
# removing:  4
# going downstream
# isomer_queue [7]
# removing:  7
# going downstream
# isomer_queue []
# removed downstream:  []
# removed downstream:  [7]
# removing:  6
# going downstream
# isomer_queue [8]
# removing:  8
# going downstream
# isomer_queue []
# removed downstream:  []
# removed downstream:  [8]
# after removal
# [1] [3]
# [1] [5]
# [1] [9]
#
#
#
#
# before removal
# [1] [2]
# [2] [1]
# [1] [3]
# [2] [4]
# [4, 2] [5]
# [2, 3] [1]
# [1, 2] [6]
# [2, 6] [1]
# [4] [2]
# [3, 1] [7]
#
#
# removed: [1, 2] [6]
#
#
# isomer_queue []
# after removal
# [1] [2]
# [2] [1]
# [1] [3]
# [2] [4]
# [4, 2] [5]
# [2, 3] [1]
# [4] [2]
# [3, 1] [7]
#
#
#
#
# before removal
# [1] [2]
# [2] [3]
# [1] [4]
# [2] [1]
# [2, 5] [5]
# [5, 3] [2]
# [5] [6]
# [4, 7] [7]
# [3, 1] [8]
# [4] [1]
#
#
# removed: [5] [6]
#
#
# isomer_queue []
# after removal
# [1] [2]
# [2] [3]
# [1] [4]
# [2] [1]
# [2, 5] [5]
# [5, 3] [2]
# [4, 7] [7]
# [3, 1] [8]
# [4] [1]
#
#
#
#
# before removal
# [1] [2]
# [1, 2] [3]
# [1] [4]
# [3] [5]
# [2] [6]
# [5, 4] [3]
# [1, 4] [7]
# [5, 8] [8]
# [1, 8] [9]
# [8, 4] [5]
#
#
# removed: [1] [2]
#
#
# isomer_queue [3, 6]
# removing:  3
# going downstream
# isomer_queue [5]
# removing:  5
# going downstream
# isomer_queue [8]
# removing:  8
# going downstream
# isomer_queue [9]
# removing:  9
# going downstream
# isomer_queue []
# removed downstream:  []
# removed downstream:  [9]
# removed downstream:  [9, 8]
# removed downstream:  [9, 8, 5]
# removing:  6
# going downstream
# isomer_queue []
# removed downstream:  []
# after removal
# [1] [4]
# [1, 4] [7]
#
#
#
#
# before removal
# [1] [2]
# [1] [3]
# [3] [1]
# [1, 3] [4]
# [1, 4] [5]
# [4, 3] [1]
# [3, 5] [1]
# [4, 3] [6]
# [1] [7]
# [4] [8]
#
#
# removed: [1] [2]
#
#
# isomer_queue []
# after removal
# [1] [3]
# [3] [1]
# [1, 3] [4]
# [1, 4] [5]
# [4, 3] [1]
# [3, 5] [1]
# [4, 3] [6]
# [1] [7]
# [4] [8]
#
#
#
#
# before removal
# [1] [2]
# [2] [1]
# [2, 1] [3]
# [1] [4]
# [3, 1] [5]
# [2, 4] [1]
# [2, 4] [6]
# [5] [7]
# [5, 1] [3]
# [6, 8] [8]
#
#
# removed: [2, 1] [3]
#
#
# isomer_queue [5]
# removing:  5
# going downstream
# isomer_queue [7]
# removing:  7
# going downstream
# isomer_queue []
# removed downstream:  []
# removed downstream:  [7]
# after removal
# [1] [2]
# [2] [1]
# [1] [4]
# [2, 4] [1]
# [2, 4] [6]
# [6, 8] [8]
#
#
#
#
# before removal
# [1] [2]
# [1] [3]
# [2] [4]
# [1] [5]
# [3, 2] [1]
# [1, 4] [6]
# [5, 1] [7]
# [2] [1]
# [5] [8]
# [3] [1]
#
#
# removed: [3, 2] [1]
#
#
# after removal
# [1] [2]
# [1] [3]
# [2] [4]
# [1] [5]
# [1, 4] [6]
# [5, 1] [7]
# [2] [1]
# [5] [8]
# [3] [1]
#
#
#
#
# before removal
# [1] [2]
# [2] [1]
# [2] [3]
# [1, 4] [4]
# [3, 2] [2]
# [2, 5] [5]
# [2, 6] [6]
# [6] [2]
# [1, 5] [7]
# [5] [8]
#
#
# removed: [3, 2] [2]
#
#
# after removal
# [1] [2]
# [2] [1]
# [2] [3]
# [1, 4] [4]
# [2, 5] [5]
# [2, 6] [6]
# [6] [2]
# [1, 5] [7]
# [5] [8]
#
#
#
#
# before removal
# [1] [2]
# [2, 1] [3]
# [1, 4] [4]
# [3] [2]
# [3] [5]
# [2, 4] [6]
# [4] [1]
# [4, 3] [1]
# [3, 4] [7]
# [4] [8]
#
#
# removed: [3, 4] [7]
#
#
# isomer_queue []
# after removal
# [1] [2]
# [2, 1] [3]
# [1, 4] [4]
# [3] [2]
# [3] [5]
# [2, 4] [6]
# [4] [1]
# [4, 3] [1]
# [4] [8]
#
#
#
#
# before removal
# [1] [2]
# [1, 3] [3]
# [1] [4]
# [3] [1]
# [3, 2] [5]
# [1] [6]
# [2, 1] [7]
# [1, 6] [8]
# [8, 7] [1]
# [7, 2] [9]
#
#
# removed: [3] [1]
#
#
# after removal
# [1] [2]
# [1, 3] [3]
# [1] [4]
# [3, 2] [5]
# [1] [6]
# [2, 1] [7]
# [1, 6] [8]
# [8, 7] [1]
# [7, 2] [9]
#
#
#
#
# before removal
# [1] [2]
# [1] [3]
# [3] [1]
# [3, 1] [1]
# [2, 1] [1]
# [2, 1] [4]
# [3, 2] [1]
# [3] [5]
# [3, 4] [6]
# [5, 6] [7]
#
#
# removed: [1] [2]
#
#
# isomer_queue [4]
# removing:  4
# going downstream
# isomer_queue [6]
# removing:  6
# going downstream
# isomer_queue [7]
# removing:  7
# going downstream
# isomer_queue []
# removed downstream:  []
# removed downstream:  [7]
# removed downstream:  [7, 6]
# after removal
# [1] [3]
# [3] [1]
# [3, 1] [1]
# [3] [5]
#
#
#
#
# before removal
# [1] [2]
# [1] [3]
# [1] [4]
# [2] [5]
# [2] [1]
# [5, 6] [6]
# [5] [7]
# [6, 2] [5]
# [7, 3] [8]
# [1] [9]
#
#
# removed: [1] [2]
#
#
# isomer_queue [5, 5]
# removing:  5
# going downstream
# isomer_queue [6, 7]
# removing:  6
# going downstream
# isomer_queue []
# removed downstream:  []
# removing:  7
# going downstream
# isomer_queue [8]
# removing:  8
# going downstream
# isomer_queue []
# removed downstream:  []
# removed downstream:  [8]
# removed downstream:  [8, 6, 7]
# after removal
# [1] [3]
# [1] [4]
# [1] [9]
#
#
#
#
# before removal
# [1] [2]
# [1] [3]
# [1] [4]
# [4, 3] [1]
# [2] [5]
# [2] [1]
# [1] [6]
# [4, 5] [7]
# [2, 6] [1]
# [7] [4]
#
#
# removed: [2] [5]
#
#
# isomer_queue [7]
# removing:  7
# going downstream
# isomer_queue []
# removed downstream:  []
# after removal
# [1] [2]
# [1] [3]
# [1] [4]
# [4, 3] [1]
# [2] [1]
# [1] [6]
# [2, 6] [1]
#
#
#
#
# before removal
# [1] [2]
# [2] [1]
# [2, 1] [3]
# [3] [2]
# [2, 4] [4]
# [2, 1] [5]
# [4, 5] [2]
# [3, 1] [6]
# [4] [2]
# [6, 3] [3]
#
#
# removed: [3, 1] [6]
#
#
# isomer_queue []
# after removal
# [1] [2]
# [2] [1]
# [2, 1] [3]
# [3] [2]
# [2, 4] [4]
# [2, 1] [5]
# [4, 5] [2]
# [4] [2]
#
#
#
#
# before removal
# [1] [2]
# [1, 3] [3]
# [1] [4]
# [2] [5]
# [1, 2] [6]
# [4, 6] [7]
# [6, 1] [1]
# [5, 3] [8]
# [1] [9]
# [3, 1] [1]
#
#
# removed: [1, 3] [3]
#
#
# isomer_queue [8]
# removing:  8
# going downstream
# isomer_queue []
# removed downstream:  []
# after removal
# [1] [2]
# [1] [4]
# [2] [5]
# [1, 2] [6]
# [4, 6] [7]
# [6, 1] [1]
# [1] [9]
#
#
#
#
# before removal
# [1] [2]
# [2, 3] [3]
# [1] [4]
# [4] [5]
# [4] [1]
# [3, 2] [2]
# [2, 3] [6]
# [5, 2] [7]
# [6, 8] [8]
# [2, 4] [3]
#
#
# removed: [5, 2] [7]
#
#
# isomer_queue []
# after removal
# [1] [2]
# [2, 3] [3]
# [1] [4]
# [4] [5]
# [4] [1]
# [3, 2] [2]
# [2, 3] [6]
# [6, 8] [8]
# [2, 4] [3]
#
#
#
#
# before removal
# [1] [2]
# [1] [3]
# [3] [4]
# [3] [5]
# [2, 1] [1]
# [4, 5] [6]
# [6, 3] [4]
# [3, 5] [7]
# [1, 4] [8]
# [2, 1] [9]
#
#
# removed: [3, 5] [7]
#
#
# isomer_queue []
# after removal
# [1] [2]
# [1] [3]
# [3] [4]
# [3] [5]
# [2, 1] [1]
# [4, 5] [6]
# [6, 3] [4]
# [1, 4] [8]
# [2, 1] [9]
#
#
#
#
# before removal
# [1] [2]
# [1] [3]
# [1] [4]
# [1, 3] [5]
# [5] [1]
# [1, 6] [6]
# [3, 5] [7]
# [5] [8]
# [5] [9]
# [1] [10]
#
#
# removed: [5] [8]
#
#
# isomer_queue []
# after removal
# [1] [2]
# [1] [3]
# [1] [4]
# [1, 3] [5]
# [5] [1]
# [1, 6] [6]
# [3, 5] [7]
# [5] [9]
# [1] [10]
#
#
#
#
# before removal
# [1] [2]
# [2, 3] [3]
# [2] [1]
# [3] [4]
# [2, 1] [5]
# [2] [6]
# [6] [2]
# [5, 1] [2]
# [3, 6] [2]
# [6, 5] [7]
#
#
# removed: [1] [2]
#
#
# isomer_queue [3, 5, 6]
# removing:  3
# going downstream
# isomer_queue [4]
# removing:  4
# going downstream
# isomer_queue []
# removed downstream:  []
# removed downstream:  [4]
# removing:  5
# going downstream
# isomer_queue [7]
# removing:  7
# going downstream
# isomer_queue []
# removed downstream:  []
# removed downstream:  [7]
# removing:  6
# going downstream
# isomer_queue []
# removed downstream:  []
# after removal
#
#
#
#
# before removal
# [1] [2]
# [2, 3] [3]
# [2, 1] [1]
# [1] [4]
# [4, 1] [1]
# [2] [5]
# [2] [6]
# [1, 4] [7]
# [1] [8]
# [7] [1]
#
#
# removed: [1, 4] [7]
#
#
# isomer_queue []
# after removal
# [1] [2]
# [2, 3] [3]
# [2, 1] [1]
# [1] [4]
# [4, 1] [1]
# [2] [5]
# [2] [6]
# [1] [8]
#
#
#
#
# before removal
# [1] [2]
# [1] [3]
# [3, 4] [4]
# [4] [3]
# [3] [1]
# [3, 4] [5]
# [4] [6]
# [1, 7] [7]
# [1] [8]
# [2] [9]
#
#
# removed: [1, 7] [7]
#
#
# isomer_queue []
# after removal
# [1] [2]
# [1] [3]
# [3, 4] [4]
# [4] [3]
# [3] [1]
# [3, 4] [5]
# [4] [6]
# [1] [8]
# [2] [9]
#
#
#
#
# before removal
# [1] [2]
# [1] [3]
# [3, 2] [1]
# [2] [4]
# [4] [5]
# [4] [6]
# [6] [7]
# [4] [8]
# [3] [9]
# [5, 3] [4]
#
#
# removed: [1] [2]
#
#
# isomer_queue [4]
# removing:  4
# going downstream
# isomer_queue [5, 6, 8]
# removing:  5
# going downstream
# isomer_queue []
# removed downstream:  []
# removing:  6
# going downstream
# isomer_queue [7]
# removing:  7
# going downstream
# isomer_queue []
# removed downstream:  []
# removed downstream:  [7]
# removing:  8
# going downstream
# isomer_queue []
# removed downstream:  []
# removed downstream:  [5, 6, 8]
# after removal
# [1] [3]
# [3] [9]
#
#
#
#
# before removal
# [1] [2]
# [1, 2] [3]
# [3] [1]
# [2, 1] [4]
# [3, 5] [5]
# [5] [3]
# [5, 2] [6]
# [3, 4] [7]
# [3, 6] [5]
# [3] [8]
#
#
# removed: [1] [2]
#
#
# isomer_queue [3, 4, 6]
# removing:  3
# going downstream
# isomer_queue [5, 7, 5, 8]
# removing:  5
# going downstream
# isomer_queue [6]
# removing:  6
# going downstream
# isomer_queue []
# removed downstream:  []
# removed downstream:  [6]
# removing:  7
# going downstream
# isomer_queue []
# removed downstream:  []
# removing:  8
# going downstream
# isomer_queue []
# removed downstream:  []
# removed downstream:  [5, 7, 8]
# removing:  4
# going downstream
# isomer_queue []
# removed downstream:  []
# removing:  6
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-5a070c9fa874> in <module>()
#      19     N_remove = 1
#      20     for i in range(0, N_remove):
# ---> 21         cell.remove_protein_modification()
#      22         protein_list.append(cell.proteins)
#      23         rxn_list.append(cell.reactions)
#
# /Users/Sebi/Documents/GradSchool/Evolution_of_GRNs/Evolution_of_GRN/WithReversibility/modules/cells.py in remove_protein_modification(self, rxn_removed)
#     598
#     599             # remove all protein isomers and their dependencies
# --> 600             self.remove_isomers(modified_protein)
#     601
#     602
#
# /Users/Sebi/Documents/GradSchool/Evolution_of_GRNs/Evolution_of_GRN/WithReversibility/modules/cells.py in remove_isomers(self, protein)
#     263                 # remove isomer from cell
#     264                 print('removing: ', isomer)
# --> 265                 self.proteins.remove(isomer)
#     266                 self.modified_proteins.remove(isomer)
#     267                 direct_isomers_removed.append(isomer)
#
# ValueError: list.remove(x): x not in list

# %%
functools.reduct([True, True])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-158-585ce5b3e674> in <module>()
# ----> 1 functools.reduct([True, True])
#
# AttributeError: 'module' object has no attribute 'reduct'

# %%
for i, rxns in enumerate(rxn_list):
    print('Round:', i)
    print('\n Protein set:')
    print(protein_list[i])
    print('\n Reaction set:')
    for rxn in rxns:
        if rxn.rxn_type in ['modification', 'catalytic_modification']:
            print(rxn.reactants, rxn.products)
# Out:
# Round: 0
#
#  Protein set:
# [1, 2]
#
#  Reaction set:
# [1] [2]
# [3] [2]
# [2] [3]
# Round: 1
#
#  Protein set:
# [1, 2]
#
#  Reaction set:
# [1] [2]
# [2] [3]

# %%
# initialize cell with one gene
custom_cell = Cell(name=1, initial_genes=1)

# add first mod to produce protein 2
custom_cell.add_protein_modification()

# add second mod to produce protein 3
custom_cell.add_protein_modification(substrate=2, reversibility_bias=0)


        
# add reverse rxn from 3 to 2
custom_cell.add_protein_modification(substrate=3, product=2)



print('before removal')
print('\n Protein set:')
print(custom_cell.proteins)
print('\n Reaction set:')
for rxn in custom_cell.reactions:
    if rxn.rxn_type in ['modification', 'catalytic_modification']:
        print(rxn.reactants, rxn.products)

        
# remove production of third protein
rxn_removed = custom_cell.reactions[-2]
custom_cell.remove_protein_modification(rxn_removed)

print('\n\n')
print('after removal')
print('\n Protein set:')
print(custom_cell.proteins)
print('\n Reaction set:')
for rxn in custom_cell.reactions:
    if rxn.rxn_type in ['modification', 'catalytic_modification']:
        print(rxn.reactants, rxn.products)



custom_cell.show_topology()
# Out:
# before removal
#
#  Protein set:
# [1, 2, 3]
#
#  Reaction set:
# [1] [2]
# [2] [3]
# [3, 2] [2]
# [2] [3]
#
#
#
# after removal
#
#  Protein set:
# [1, 2]
#
#  Reaction set:
# [1] [2]
